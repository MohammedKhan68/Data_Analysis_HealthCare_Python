# %%
import pandas as pd
car_home = {'name':['Wagonr_Pride', 'Ameo', 'Wagonr_stingray', 'Sonet'],
            'Brand' : ['Suzuki', 'VW', 'Suzuki', 'Kia'],
            'Year_bought' : [2002, 2016, 2018, 2022]},

# %%
df_car = pd.DataFrame(car_home, index=['car_1','car_2','car_3', 'car_4'])
df_car
# Out:
#                   name   Brand  Year_bought
# car_1     Wagonr_Pride  Suzuki         2002
# car_2             Ameo      VW         2016
# car_3  Wagonr_stingray  Suzuki         2018
# car_4            Sonet     Kia         2022

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\pc'

# %%
os.chdir("C:/Users/pc/Documents/data")
os.getcwd()
# Out:
# 'C:\\Users\\pc\\Documents\\data'

# %%
health_data = pd.read_csv("cardio_base.csv")

# %%
health_data
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  smoke
# 0          0  18393       2     168    62.0    110     80            1      0
# 1          1  20228       1     156    85.0    140     90            3      0
# 2          2  18857       1     165    64.0    130     70            3      0
# 3          3  17623       2     169    82.0    150    100            1      0
# 4          4  17474       1     156    56.0    100     60            1      0
# ...      ...    ...     ...     ...     ...    ...    ...          ...    ...
# 69995  99993  19240       2     168    76.0    120     80            1      1
# 69996  99995  22601       1     158   126.0    140     90            2      0
# 69997  99996  19066       2     183   105.0    180     90            3      0
# 69998  99998  22431       1     163    72.0    135     80            1      0
# 69999  99999  20540       1     170    72.0    120     80            2      0
#
# [70000 rows x 9 columns]

# %%
health_data.head(10)
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  smoke
# 0   0  18393       2     168    62.0    110     80            1      0
# 1   1  20228       1     156    85.0    140     90            3      0
# 2   2  18857       1     165    64.0    130     70            3      0
# 3   3  17623       2     169    82.0    150    100            1      0
# 4   4  17474       1     156    56.0    100     60            1      0
# 5   8  21914       1     151    67.0    120     80            2      0
# 6   9  22113       1     157    93.0    130     80            3      0
# 7  12  22584       2     178    95.0    130     90            3      0
# 8  13  17668       1     158    71.0    110     70            1      0
# 9  14  19834       1     164    68.0    110     60            1      0

# %%
health_data.shape
# Out:
# (70000, 9)

# %%
health_data['age'] = round(health_data['age']/365)

# %%
health_data.head()
# Out:
#    id  age  gender  height  weight  ap_hi  ap_lo  cholesterol  smoke
# 0   0  0.0       2     168    62.0    110     80            1      0
# 1   1  0.0       1     156    85.0    140     90            3      0
# 2   2  0.0       1     165    64.0    130     70            3      0
# 3   3  0.0       2     169    82.0    150    100            1      0
# 4   4  0.0       1     156    56.0    100     60            1      0

# %%
health_data = pd.read_csv("cardio_base.csv")

# %%
health_data.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  smoke
# 0   0  18393       2     168    62.0    110     80            1      0
# 1   1  20228       1     156    85.0    140     90            3      0
# 2   2  18857       1     165    64.0    130     70            3      0
# 3   3  17623       2     169    82.0    150    100            1      0
# 4   4  17474       1     156    56.0    100     60            1      0

# %%
health_data['age'] = round(health_data['age']/365,0)

# %%
health_data
# Out:
#           id   age  gender  height  weight  ap_hi  ap_lo  cholesterol  smoke
# 0          0  50.0       2     168    62.0    110     80            1      0
# 1          1  55.0       1     156    85.0    140     90            3      0
# 2          2  52.0       1     165    64.0    130     70            3      0
# 3          3  48.0       2     169    82.0    150    100            1      0
# 4          4  48.0       1     156    56.0    100     60            1      0
# ...      ...   ...     ...     ...     ...    ...    ...          ...    ...
# 69995  99993  53.0       2     168    76.0    120     80            1      1
# 69996  99995  62.0       1     158   126.0    140     90            2      0
# 69997  99996  52.0       2     183   105.0    180     90            3      0
# 69998  99998  61.0       1     163    72.0    135     80            1      0
# 69999  99999  56.0       1     170    72.0    120     80            2      0
#
# [70000 rows x 9 columns]

# %%
health_data.drop('id', axis=1, inplace=True)

# %%
health_data
#total number of rows is 70,000; Indicats the population of data
# Out:
#         age  gender  height  weight  ap_hi  ap_lo  cholesterol  smoke
# 0      50.0       2     168    62.0    110     80            1      0
# 1      55.0       1     156    85.0    140     90            3      0
# 2      52.0       1     165    64.0    130     70            3      0
# 3      48.0       2     169    82.0    150    100            1      0
# 4      48.0       1     156    56.0    100     60            1      0
# ...     ...     ...     ...     ...    ...    ...          ...    ...
# 69995  53.0       2     168    76.0    120     80            1      1
# 69996  62.0       1     158   126.0    140     90            2      0
# 69997  52.0       2     183   105.0    180     90            3      0
# 69998  61.0       1     163    72.0    135     80            1      0
# 69999  56.0       1     170    72.0    120     80            2      0
#
# [70000 rows x 8 columns]

# %%
#lets find number of female & Male
health_data.loc[health_data['gender']==2]
# Out:
#         age  gender  height  weight  ap_hi  ap_lo  cholesterol  smoke
# 0      50.0       2     168    62.0    110     80            1      0
# 3      48.0       2     169    82.0    150    100            1      0
# 7      62.0       2     178    95.0    130     90            3      0
# 11     52.0       2     173    60.0    120     80            1      0
# 12     41.0       2     165    60.0    120     80            1      0
# ...     ...     ...     ...     ...    ...    ...          ...    ...
# 69981  48.0       2     182   110.0    130     90            2      0
# 69984  49.0       2     168    80.0    120     80            1      0
# 69986  50.0       2     180    78.0    120     80            1      0
# 69995  53.0       2     168    76.0    120     80            1      1
# 69997  52.0       2     183   105.0    180     90            3      0
#
# [24470 rows x 8 columns]

# %%
total_population = 70000
n_females = 24470
percentage_females = (n_females/total_population)*100
percentage_females
percentage_males = 100-percentage_females
print("The % of females is ", round(percentage_females))
print("The % of males is ", round(percentage_males))
# Out:
# The % of females is  35
# The % of males is  65

# %%
#lets calculate percentage of cholesterol levels 

#level-1
L1_chol = health_data.loc[health_data['cholesterol']==1]
n_L1 = L1_chol.shape[0]
n_L1
percentage_L1 = round((n_L1/total_population)*100)
print("The % of population with L1 cholesterol level is", percentage_L1, "%")
# Out:
# The % of population with L1 cholesterol level is 75 %

# %%
L2_chol = health_data.loc[health_data['cholesterol']==2]
n_L2 = L2_chol.shape[0]
n_L2
percentage_L2 = round((n_L2/total_population)*100)
print("The % of population with L1 cholesterol level is", percentage_L2, "%")
# Out:
# The % of population with L1 cholesterol level is 14 %

# %%
L3_chol = health_data.loc[health_data['cholesterol']==3]
n_L3 = L3_chol.shape[0]
n_L3
percentage_L3 = round((n_L3/total_population)*100)
print("The % of population with L1 cholesterol level is", percentage_L3, "%")
# Out:
# The % of population with L1 cholesterol level is 12 %

# %%
health_data.head()
# Out:
#     age  gender  height  weight  ap_hi  ap_lo  cholesterol  smoke
# 0  50.0       2     168    62.0    110     80            1      0
# 1  55.0       1     156    85.0    140     90            3      0
# 2  52.0       1     165    64.0    130     70            3      0
# 3  48.0       2     169    82.0    150    100            1      0
# 4  48.0       1     156    56.0    100     60            1      0

# %%
percentage_cholesterol = {'level' : [1,2,3],
                          'percentage' : [percentage_L1, percentage_L2, percentage_L3]}
df_cholesterol_level = pd.DataFrame(percentage_cholesterol)
df_cholesterol_level
# Out:
#    level  percentage
# 0      1          75
# 1      2          14
# 2      3          12

# %%
health_data.describe()
# Out:
#                 age        gender        height        weight         ap_hi  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean      53.338686      1.349571    164.359229     74.205690    128.817286
# std        6.765294      0.476838      8.210126     14.395757    154.011419
# min       30.000000      1.000000     55.000000     10.000000   -150.000000
# 25%       48.000000      1.000000    159.000000     65.000000    120.000000
# 50%       54.000000      1.000000    165.000000     72.000000    120.000000
# 75%       58.000000      2.000000    170.000000     82.000000    140.000000
# max       65.000000      2.000000    250.000000    200.000000  16020.000000
#
#               ap_lo   cholesterol         smoke
# count  70000.000000  70000.000000  70000.000000
# mean      96.630414      1.366871      0.088129
# std      188.472530      0.680250      0.283484
# min      -70.000000      1.000000      0.000000
# ...

# %%
health_data['gender'].value_counts()
# Out:
# gender
# 1    45530
# 2    24470
# Name: count, dtype: int64

# %%
#Average Weight and Height by gender

male_data = health_data.loc[health_data['gender'] == 1]
female_data = health_data.loc[health_data['gender'] == 2]

print('The avg weight of Male is ', round(male_data['weight'].mean()),'kgs')
print('The avg height of Male is ', round(male_data['height'].mean()), 'cm')
print('The avg weight of Female is ', round(female_data['weight'].mean()), 'kgs')
print('the avg height of Female is ', round(female_data['height'].mean()), 'cm')
# Out:
# The avg weight of Male is  73 kgs
# The avg height of Male is  161 cm
# The avg weight of Female is  77 kgs
# the avg height of Female is  170 cm

# %%
health_data['age'] = health_data['age'].astype('int')
health_data['age'].unique()
# Out:
# array([50, 55, 52, 48, 60, 61, 62, 54, 41, 40, 46, 58, 59, 63, 64, 57, 56,
#        49, 51, 44, 65, 45, 53, 47, 42, 39, 43, 30])

# %%
health_data
# Out:
#        age  gender  height  weight  ap_hi  ap_lo  cholesterol  smoke
# 0       50       2     168    62.0    110     80            1      0
# 1       55       1     156    85.0    140     90            3      0
# 2       52       1     165    64.0    130     70            3      0
# 3       48       2     169    82.0    150    100            1      0
# 4       48       1     156    56.0    100     60            1      0
# ...    ...     ...     ...     ...    ...    ...          ...    ...
# 69995   53       2     168    76.0    120     80            1      1
# 69996   62       1     158   126.0    140     90            2      0
# 69997   52       2     183   105.0    180     90            3      0
# 69998   61       1     163    72.0    135     80            1      0
# 69999   56       1     170    72.0    120     80            2      0
#
# [70000 rows x 8 columns]

# %%
#Cholesterol distribution across different age groups
age_cholesterol = health_data.groupby(['age']).cholesterol.count()
age_cholesterol
# Out:
# age
# 30       4
# 39     409
# 40    2700
# 41     766
# 42    2624
# 43     690
# 44    2837
# 45     757
# 46    2955
# 47     754
# 48    3194
# 49    1059
# 50    5267
# 51    1348
# 52    5303
# 53    1407
# 54    5988
# 55    1498
# 56    6031
# 57    1452
# 58    5702
# 59    1355
# 60    5465
# 61    1221
# 62    3926
# 63    1016
# 64    3920
# 65     352
# Name: cholesterol, dtype: int64

# %%
import matplotlib.pyplot as plt
age_cholesterol.plot(kind='bar', figsize=(10,5), color='skyblue')
plt.title("Cholesterol count by Age")
plt.xlabel("Age - Years")
plt.ylabel("No. of people")
plt.tight_layout()

# %%
#Cholesterol distribution across different age groups and different label

age_chol_levels = health_data.groupby(['age','cholesterol']).cholesterol.count()
age_chol_levels
# Out:
# age  cholesterol
# 30   1                 4
# 39   1               341
#      2                52
#      3                16
# 40   1              2330
#                     ...
# 64   2               548
#      3               797
# 65   1               274
#      2                47
#      3                31
# Name: cholesterol, Length: 82, dtype: int64

# %%
age_chol_levels_df = age_chol_levels.unstack()
age_chol_levels_df
# Out:
# cholesterol       1      2      3
# age
# 30              4.0    NaN    NaN
# 39            341.0   52.0   16.0
# 40           2330.0  281.0   89.0
# 41            634.0   96.0   36.0
# 42           2224.0  308.0   92.0
# 43            526.0  112.0   52.0
# 44           2358.0  330.0  149.0
# 45            603.0  107.0   47.0
# 46           2414.0  375.0  166.0
# 47            593.0   99.0   62.0
# 48           2525.0  456.0  213.0
# 49            820.0  157.0   82.0
# 50           4146.0  695.0  426.0
# 51           1030.0  182.0  136.0
# 52           4055.0  735.0  513.0
# 53           1050.0  195.0  162.0
# 54           4522.0  830.0  636.0
# 55           1116.0  203.0  179.0
# 56           4375.0  843.0  813.0
# 57           1022.0  204.0  226.0
# 58           4046.0  820.0  836.0
# 59            921.0  199.0  235.0
# 60           3787.0  773.0  905.0
# 61            790.0  180.0  251.0
# 62           2666.0  558.0  702.0
# 63            638.0  164.0  214.0
# ...

# %%
age_chol_levels_df.plot(kind = 'bar', figsize=(10,5))
# Out:
# <Axes: xlabel='age'>

# %%
#Percentage of smokers in the dataset
count_smokers = (health_data.loc[health_data['smoke']==1]).shape[0]
Percentage_smokers = (count_smokers/total_population)*100
print("The % of smokers is ", round(Percentage_smokers), "%")
# Out:
# The % of smokers is  9 %

# %%
#Minimum, maximum, and average blood pressure values (ap_hi and ap_low)
print("the minimum high blood pressure is ", health_data['ap_hi'].min())
print("the minimum high blood pressure is ", health_data['ap_hi'].max())
print("the minimum high blood pressure is ", health_data['ap_hi'].mean())

print("the minimum low blood pressure is ", health_data['ap_lo'].min())
print("the minimum low blood pressure is ", health_data['ap_lo'].max())
print("the minimum low blood pressure is ", health_data['ap_lo'].mean())
# Out:
# the minimum high blood pressure is  -150
# the minimum high blood pressure is  16020
# the minimum high blood pressure is  128.8172857142857
# the minimum low blood pressure is  -70
# the minimum low blood pressure is  11000
# the minimum low blood pressure is  96.63041428571428

# %%
#Do smokers tend to have higher cholesterol levels compared to non-smokers?

# %%
n_hi_chol_smokers = health_data.loc[(health_data['cholesterol']==3) & (health_data['smoke'] == 1)].shape[0]
n_hi_chol_smokers
# Out:
# 697

# %%
n_hi_chol_non_smokers = health_data.loc[(health_data['cholesterol']==3) & (health_data['smoke'] == 0)].shape[0]
n_hi_chol_non_smokers
# Out:
# 7369

# %%
#There are less smokers when compared to non-smokers when compared to higher cholesterol levels

# %%
#Is there a significant difference in blood pressure between males and females?

health_data
# Out:
#        age  gender  height  weight  ap_hi  ap_lo  cholesterol  smoke
# 0       50       2     168    62.0    110     80            1      0
# 1       55       1     156    85.0    140     90            3      0
# 2       52       1     165    64.0    130     70            3      0
# 3       48       2     169    82.0    150    100            1      0
# 4       48       1     156    56.0    100     60            1      0
# ...    ...     ...     ...     ...    ...    ...          ...    ...
# 69995   53       2     168    76.0    120     80            1      1
# 69996   62       1     158   126.0    140     90            2      0
# 69997   52       2     183   105.0    180     90            3      0
# 69998   61       1     163    72.0    135     80            1      0
# 69999   56       1     170    72.0    120     80            2      0
#
# [70000 rows x 8 columns]

# %%
health_data.groupby('gender')[['ap_hi', 'ap_lo']].mean()
# Out:
#              ap_hi       ap_lo
# gender
# 1       128.139249   94.522776
# 2       130.078872  100.551982

# %%
sns.boxplot(x='gender', y = 'ap_hi', data = health_data)
# Out:
# <Axes: xlabel='gender', ylabel='ap_hi'>

# %%
sns.boxplot(x='gender', y = 'ap_lo', data = health_data)
# Out:
# <Axes: xlabel='gender', ylabel='ap_lo'>

# %%
health_data['BMI'] = (health_data['weight']/(pow(health_data['height']/100,2)))

# %%
health_data
# Out:
#        age  gender  height  weight  ap_hi  ap_lo  cholesterol  smoke  \
# 0       50       2     168    62.0    110     80            1      0
# 1       55       1     156    85.0    140     90            3      0
# 2       52       1     165    64.0    130     70            3      0
# 3       48       2     169    82.0    150    100            1      0
# 4       48       1     156    56.0    100     60            1      0
# ...    ...     ...     ...     ...    ...    ...          ...    ...
# 69995   53       2     168    76.0    120     80            1      1
# 69996   62       1     158   126.0    140     90            2      0
# 69997   52       2     183   105.0    180     90            3      0
# 69998   61       1     163    72.0    135     80            1      0
# 69999   56       1     170    72.0    120     80            2      0
#
#              BMI
# 0      21.967120
# 1      34.927679
# 2      23.507805
# 3      28.710479
# 4      23.011177
# ...          ...
# ...

# %%
#How does BMI (Body Mass Index) differ between males and females?

health_data.groupby('gender').BMI.mean()
# Out:
# gender
# 1    27.987583
# 2    26.754442
# Name: BMI, dtype: float64

# %%
sns.barplot(x='gender', y='BMI', data=health_data)
# Out:
# <Axes: xlabel='gender', ylabel='BMI'>

# %%
sns.histplot(data=health_data, x='BMI', hue='gender', kde=True, element='step', palette='Set2')
# Out:
# <Axes: xlabel='BMI', ylabel='Count'>

# %%
sns.scatterplot(data=health_data, x='age', y='BMI',hue='gender', alpha=0.6)
# Out:
# <Axes: xlabel='age', ylabel='BMI'>

# %%
#Does age have a correlation with cholesterol levels?


sns.lineplot(data= health_data, x = 'age', y= 'cholesterol', hue = 'gender', alpha=1, palette='dark')
# Out:
# <Axes: xlabel='age', ylabel='cholesterol'>

# %%
correlation = health_data['age'].corr(health_data['cholesterol'])
print(f"Correlation between age and cholesterol: {correlation}")

#Close to +1 → strong positive correlation

#Close to 0 → no correlation

#Close to –1 → strong negative correlation
# Out:
# Correlation between age and cholesterol: 0.15438601560811274

# %%
#Do males have a higher smoking rate than females?

count_males_smokers = health_data.loc[(health_data['gender']==1) & (health_data['smoke']==1)].shape[0]
count_males_smokers

print(count_males_smokers)

count_male = health_data.loc[health_data['gender']==1].shape[0]
print(count_male)

per_male = round((count_males_smokers/count_male)*100)
per_male
# Out:
# 813
# 45530
# 2

# %%
count_females_smokers = health_data.loc[(health_data['gender']==2) & (health_data['smoke']==1)].shape[0]
count_females_smokers

per_female = round((count_females_smokers/n_females)*100)

print(per_female)
# Out:
# 22

# %%
#female smokers are more than male smokers
